# %%
import pandas as pd

df = pd.read_csv('Top_Apps_in_Google_Play.csv')

print(df.head(7))
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.iloc[:, :3])
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.head(1))


df
# Out:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# 6                    com.google.android.gm            Communication
#
# ...

# %%
import pandas as pd

df = pd.read_csv('crypto.csv')

print(df.head(7))
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.iloc[:, :3])
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.head(1))

df
# Out:
#                                                                                                                                                                                                    # **Cryptocurrency Prediction with Artificial Intelligence V3.0 [GRU Neural Network]**
# I am pleased to announce with you the V3.0 of m... I use the GRU Neural Network whose algorithms that I have designed myself. T... MAE score: 0.02262356696266076 MSE score: 0.0008216340443992631   Accuracy: 98.5220357283052. Another element t...
# Best wishes                                        NaN                          NaN                                                NaN                            NaN                                                                             NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('programming language trend over time.csv')

print(df.head(7))
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.iloc[:, :3])
print("-------------------------------------------------------------------------------------")
print("-------------------------------------------------------------------------------------")
print(df.head(1))

df
# Out:
#         Week  Python  Java  C++
# 0  4/21/2019      55    55   18
# 1  4/28/2019      52    50   16
# 2   5/5/2019      56    56   17
# 3  5/12/2019      56    61   18
# 4  5/19/2019      57    56   17
# 5  5/26/2019      55    57   17
# 6   6/2/2019      54    58   15
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
#           Week  Python  Java
# 0    4/21/2019      55    55
# 1    4/28/2019      52    50
# 2     5/5/2019      56    56
# 3    5/12/2019      56    61
# 4    5/19/2019      57    56
# ..         ...     ...   ...
# 257  3/24/2024      79    47
# 258  3/31/2024      81    51
# 259   4/7/2024      77    45
# 260  4/14/2024      78    48
# 261  4/21/2024      71    42
#
# [262 rows x 3 columns]
# -------------------------------------------------------------------------------------
# ...
